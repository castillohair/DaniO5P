# %% [markdown]
# # DaniO5P RNN training and evaluation
#
# This notebook trains and evaluates an ensemble of recurrent neural networks (RNNs). These models take an input sequence and generate predictions of $log_2MRL^{t_i}$ for every timepoint $t_i$, and $Δlog_2X^{t_i - t_{i-1}}$ for every time interval $t_i - t_{i-1}$, for a total of 8 outputs.
#
# Note that the predicted quantities are the *residuals* from the length model and not the actual measurements. To obtain a full prediction on measured quantities, RNN predictions must be added to length model predictions.
#
# Models are trained in a 10-fold cross validation scheme based on chromosome splits: sequences from different chromosomes are used for either training/validation/testing of each model, and every chromosome is in the test set of exactly one model. Chromosome splits are generated in `generate_chr_splits.ipynb`.
#
# After training, predictions are made on the test set of each model and saved to `Zb_5UTR_MPRA_rnn_test_predictions.tsv.gz`. $r^2$ are calculated based on these predictions and saved to `performance_rnn_test_r2.csv`. Finally, predictions are made using the full ensemble (average output of all models) and saved to `Zb_5UTR_MPRA_rnn_ensemble_predictions.tsv.gz`.
#
# Notes about input lengths:
# This model uses RNNs with the linear attention mechanism ([Bahdanau et al. 2017](https://arxiv.org/abs/1409.0473)). The input of this model can have, in principle, any length. Furthermore, the linear attention mechanism has been shown to generalize to some extent to inputs longer than the training dataset in the context of language processing. However, for zebrafish enbryogenesis genetics, its performance beyond 238bp has not been experimentally validated, so use with caution.

# %%
import json
import os
import sys

import numpy
import matplotlib
from matplotlib import pyplot
import pickle
import pandas
import scipy
import seaborn
import tensorflow
from tensorflow.keras import layers
from tensorflow.keras import models

utils_dir = '../utils'
sys.path.append(utils_dir)
import custom_plots
import seq_utils
import rnn_attn

# %%
# %matplotlib inline
matplotlib.rcParams['figure.dpi'] = 120
matplotlib.rcParams['font.sans-serif'] = 'Arial'

# %% [markdown]
# # Read data

# %%
timepoint_list = [2, 4, 6, 10]

lib_tpm_col = 'TPM_library'
log2_lib_tpm_col = 'log2_TPM_library'

log2_mrl_cols = [f'log2_MRL_{t}hpf' for t in timepoint_list]
delta_log2_x_cols = [f'Δlog2_X_{t}hpf' for t in timepoint_list]

res_log2_mrl_cols = [f'res_log2_MRL_{t}hpf' for t in timepoint_list]
res_delta_log2_x_cols = [f'res_Δlog2_X_{t}hpf' for t in timepoint_list]

log2_x_cols = [f'log2_X_{t}hpf' for t in timepoint_list]

# %%
# Load data
data_full = pandas.read_csv(
    '../preprocess_data/Zb_5UTR_MPRA_preprocessed.tsv.gz',
    index_col=0,
    sep='\t',
)
# Add residuals
data_residuals = pandas.read_csv(
    '../length_model/Zb_5UTR_MPRA_len_residuals.tsv.gz',
    index_col=0,
    sep='\t',
)
data_full = pandas.concat([data_full, data_residuals], axis=1)

data_full
# Out:
#                                                       chr strand  \
# ENSDARG00000000001_ENSDART00000000004_19058_slc...   chr9      -
# ENSDARG00000000018_ENSDART00000181044_14421_nrf...   chr4      -
# ENSDARG00000000019_ENSDART00000124452_14118_ube...   chr4      +
# ENSDARG00000000068_ENSDART00000000069_2438_slc9...  chr12      +
# ENSDARG00000000069_ENSDART00000000070_12170_dap...  chr24      -
# ...                                                   ...    ...
# ENSDARG00000025554_ENSDART00000103273_1746_wdr8...  chr11      +
# ENSDARG00000103318_ENSDART00000161570_7325_mrpl...  chr19      +
# ENSDARG00000036698_ENSDART00000053300_7697_znf8...  chr19      -
# ENSDARG00000056892_ENSDART00000148517_5556_mpp6
# ENSDARG00000056892_ENSDART00000148517_5556_mpp6...          0.115763
# ENSDARG00000060768_ENSDART00000133628_7544_anki...         -0.354212
#
#                                                     res_Δlog2_X_10hpf
# ENSDARG00000000001_ENSDART00000000004_19058_slc...          -0.216314
# ENSDARG00000000018_ENSDART00000181044_14421_nrf...          -0.209622
# ENSDARG00000000019_ENSDART00000124452_14118_ube...          -0.312300
# ENSDARG00000000068_ENSDART00000000069_2438_slc9...           0.558087
# ENSDARG00000000069_ENSDART00000000070_12170_dap...           0.143177
# ...                                                               ...
# ENSDARG00000025554_ENSDART00000103273_1746_wdr8...          -0.250690
# ENSDARG00000103318_ENSDART00000161570_7325_mrpl...          -0.613514
# ENSDARG00000036698_ENSDART00000053300_7697_znf8...          -0.311490
# ENSDARG00000056892_ENSDART00000148517_5556_mpp6...           0.074736
# ENSDARG00000060768_ENSDART00000133628_7544_anki...           0.735325
#
# [18021 rows x 86 columns]

# %%
# Used later for one-hot encoding
max_seq_len = int(data_full['insert_length'].max())

# %%
# Preserve only rows with input tpm above threshold
tpm_threshold = 3
data = data_full[data_full[lib_tpm_col] > tpm_threshold]
print(f"{len(data_full):,} total sequences, {len(data):,} retained.")
data
# Out:
# 18,021 total sequences, 17,951 retained.
#                                                       chr strand  \
# ENSDARG00000000001_ENSDART00000000004_19058_slc...   chr9      -
# ENSDARG00000000018_ENSDART00000181044_14421_nrf...   chr4      -
# ENSDARG00000000019_ENSDART00000124452_14118_ube...   chr4      +
# ENSDARG00000000068_ENSDART00000000069_2438_slc9...  chr12      +
# ENSDARG00000000069_ENSDART00000000070_12170_dap...  chr24      -
# ...                                                   ...    ...
# ENSDARG00000060397_ENSDART00000085051_231_hhip_...   chr1      +
# ENSDARG00000098284_ENSDART00000170620_10459_ctx...  chr22      +
# ENSDARG00000103318_ENSDART00000161570_7325_mrpl...  chr19      +
# ENSDARG00000036698_ENSDART00000053300_7697_znf8...  chr19      -
# ENSDARG00000056892_ENSDART00000148517_5556_mpp6...  chr16      -
#
#                                                    external_gene_name  \
# ENSDARG00000000001_ENSDART00000000004_19058_slc...            slc35a5
# ENSDARG00000000018_ENSDART00000181044_14421_nrf...               nrf1
# ENSDARG00000000019_ENSDART00000124452_14118_ube...              ube2h
# ENSDARG00000000068_ENSDART00000000069_2438_slc9...          slc9a3r1a
# ENSDARG00000000069_ENSDART00000000070_12170_dap...                dap
# ...                                                               ...
# ENSDARG00000060397_ENSDART00000085051_231_hhip_...               hhip
# ENSDARG00000098284_ENSDART00000170620_10459_ctx...              ctxn1
# ENSDARG00000103318_ENSDART00000161570_7325_mrpl...              mrpl3
# ENSDARG00000036698_ENSDART00000053300_7697_znf8...             znf865
# ENSDARG00000056892_ENSDART00000148517_5556_mpp6...              mpp6a
#
#                                                     utr_length  insert_length  \
# ENSDARG00000000001_ENSDART00000000004_19058_slc...       103.0          103.0
# ENSDARG00000000018_ENSDART00000181044_14421_nrf...       134.0          134.0
# ENSDARG00000000019_ENSDART00000124452_14118_ube...       178.0          178.0
# ENSDARG00000000068_ENSDART00000000069_2438_slc9...       152.0          152.0
# ENSDARG00000000069_ENSDART00000000070_12170_dap...       153.0          153.0
# ...                                                        ...            ...
# ENSDARG00000060397_ENSDART00000085051_231_hhip_...       410.0          209.0
# ENSDARG00000098284_ENSDART00000170620_10459_ctx...       678.0          174.0
# ENSDARG00000103318_ENSDART00000161570_7325_mrpl...       111.0          111.0
# ENSDARG00000036698_ENSDART00000053300_7697_znf8...      1305.0          197.0
# ENSDARG00000056892_ENSDART00000148517_5556_mpp6...       311.0          161.0
#
#                                                     n_uORFs  GC_content  \
# ENSDARG00000000001_ENSDART00000000004_19058_slc...      2.0   52.427184
# ENSDARG00000000018_ENSDART00000181044_14421_nrf...      0.0   61.940299
# ENSDARG00000000019_ENSDART00000124452_14118_ube...      1.0   46.629213
# ENSDARG00000000068_ENSDART00000000069_2438_slc9...      0.0   46.052632
# ENSDARG00000000069_ENSDART00000000070_12170_dap...      1.0   47.058824
# ...                                                     ...         ...
# ENSDARG00000060397_ENSDART00000085051_231_hhip_...      2.0   31.578947
# ENSDARG00000098284_ENSDART00000170620_10459_ctx...      0.0   51.724138
# ENSDARG00000103318_ENSDART00000161570_7325_mrpl...      2.0   34.234234
# ENSDARG00000036698_ENSDART00000053300_7697_znf8...      4.0   31.979695
# ENSDARG00000056892_ENSDART00000148517_5556_mpp6...      1.0   39.130435
#
#                                                     mxfold     index  \
# ENSDARG00000000001_ENSDART00000000004_19058_slc...    23.9   20318.0
# ENSDARG00000000018_ENSDART00000181044_14421_nrf...    35.3   72681.0
# ENSDARG00000000019_ENSDART00000124452_14118_ube...    30.1   27446.0
# ENSDARG00000000068_ENSDART00000000069_2438_slc9...    26.1  113092.0
# ENSDARG00000000069_ENSDART00000000070_12170_dap...    31.8   20320.0
# ...                                                    ...       ...
# ENSDARG00000060397_ENSDART00000085051_231_hhip_...    26.3   26758.1
# ENSDARG00000098284_ENSDART00000170620_10459_ctx...    41.2   29429.4
# ENSDARG00000103318_ENSDART00000161570_7325_mrpl...    12.5   86762.0
# ENSDARG00000036698_ENSDART00000053300_7697_znf8...    25.9   21263.6
# ENSDARG00000056892_ENSDART00000148517_5556_mpp6...    37.6   23746.2
#
#                                                     index_base  ...  \
# ENSDARG00000000001_ENSDART00000000004_19058_slc...       20318  ...
# ENSDARG00000000018_ENSDART00000181044_14421_nrf...       72681  ...
# ENSDARG00000000019_ENSDART00000124452_14118_ube...       27446  ...
# ENSDARG00000000068_ENSDART00000000069_2438_slc9...      113092  ...
# ENSDARG00000000069_ENSDART00000000070_12170_dap...       20320  ...
# ...                                                        ...  ...
# ENSDARG00000060397_ENSDART00000085051_231_hhip_...       26758  ...
# ENSDARG00000098284_ENSDART00000170620_10459_ctx...       29429  ...
# ENSDARG00000103318_ENSDART00000161570_7325_mrpl...       86762  ...
# ENSDARG00000036698_ENSDART00000053300_7697_znf8
...
# ENSDARG00000060397_ENSDART00000085051_231_hhip_...          -1.030281
# ENSDARG00000098284_ENSDART00000170620_10459_ctx...          -0.851463
# ENSDARG00000103318_ENSDART00000161570_7325_mrpl...          -0.613514
# ENSDARG00000036698_ENSDART00000053300_7697_znf8...          -0.311490
# ENSDARG00000056892_ENSDART00000148517_5556_mpp6...           0.074736
#
# [17951 rows x 86 columns]

# %%
# Plot number of sequences vs. TPM theshold
data_tpm_min = data_full[lib_tpm_col].sort_values(ascending=False)

f, ax = pyplot.subplots(figsize=(5, 3.5))
ax.plot(range(len(data_tpm_min)), data_tpm_min)
ax.axhline(tpm_threshold, color='gray')
ax.set_xscale('log')
ax.set_xlabel('Cumulative number of sequences')
ax.set_yscale('log')
ax.set_ylabel('Minimum TPM per sequence')
# Out:
# Text(0, 0.5, 'Minimum TPM per sequence')

# %%
# Plot histogram with number of reads
pyplot.figure(figsize=(5, 3.5))
pyplot.hist(
    data_full[lib_tpm_col],
    bins=numpy.logspace(-0.2, 6, 100),
    log=True,
    label='All')
pyplot.hist(
    data[lib_tpm_col],
    bins=numpy.logspace(-0.2, 6, 100),
    log=True,
    label='Selected',
    histtype='step')
pyplot.xscale('log')
pyplot.xlabel('Library TPM per sequence')
pyplot.ylabel('Number of sequences')
pyplot.legend()

# %% [markdown]
# # Load split info
#
# Produced by the `generate_chr_splits.ipynb` notebook.

# %%
with open('chr_splits.json', 'r') as f:
    chr_splits_info = json.load(f)
# chr_splits_info

# %% [markdown]
# # Train ensemble model

# %%
# Folder for model files
models_dir = 'models_rnn_attn'
if not os.path.exists(models_dir):
    os.makedirs(models_dir)

# %%
# Bootstrapping loop
epochs = 100
batch_size = 128
learning_rate = 3e-3

for split_idx, chr_split_info in enumerate(chr_splits_info):
    print(f"Training model {split_idx + 1}/{len(chr_splits_info)}...")

    # Split data
    train_chrs = chr_split_info['train']
    val_chrs = chr_split_info['val']
    test_chrs = chr_split_info['test']

    data_train = data[data['chr'].isin(train_chrs)]
    data_val = data[data['chr'].isin(val_chrs)]
    data_test = data[data['chr'].isin(test_chrs)]

    print(f"{len(data_train):,} samples for training, {len(data_val):,} for validation, {len(data_test):,} for testing...")

    model = rnn_attn.make_model(
        # Run 1:
        rnn_units=[32, 32, 32],
        rnn_dropout=0.1,
        attn_units=32,
        dense_units=[192],
        dense_dropout=0.02,
        # # Run 2:
        # rnn_units=[48, 48],
        # rnn_dropout=0.2,
        # attn_units=32,
        # dense_units=[768],
        # dense_dropout=0.02,
        n_outputs=len(res_log2_mrl_cols + res_delta_log2_x_cols),
        layer_name_suffix=f'_chr_split_{split_idx:03d}',
    )

    # model.summary()

    # Extract input, output in the preferred format for model
    data_train_x = seq_utils.one_hot_encode(data_train['insert_seq'], padding='left', mask_val=-1)
    data_train_y = data_train[res_log2_mrl_cols + res_delta_log2_x_cols].values

    data_val_x = seq_utils.one_hot_encode(data_val['insert_seq'], padding='left', mask_val=-1)
    data_val_y = data_val[res_log2_mrl_cols + res_delta_log2_x_cols].values

    # Use Adam optimizer with decayed learning rate
    # lr = initial_lr / (1 + decay_rate * step / decay_step)
    # At 10 epochs, lr is 1/2 of initial
    # At 20 epochs, lr is 1/3 of initial
    # At 30 epochs, lr is 1/4 of initial
    lr_schedule = tensorflow.keras.optimizers.schedules.InverseTimeDecay(
        learning_rate,
        decay_steps=len(data_train)/batch_size*10,
        decay_rate=1,
        staircase=False,
    )
    optimizer = tensorflow.keras.optimizers.Adam(lr_schedule)

    # Callback: stop training after no improvement in validation
    callbacks = [
        tensorflow.keras.callbacks.EarlyStopping(
            monitor='val_loss',
            patience=10,
            restore_best_weights=True,
        ),
    ]

    # custom loss function
    # weights from standard deviation of model outputs
    data_train_y_std = data_train_y.std(axis=0)
    w = 1 / data_train_y_std
    w = numpy.expand_dims(w, axis=0)
    def custom_loss(y_true, y_pred):
        se = tensorflow.square(y_true - y_pred)
        mse = tensorflow.reduce_mean(se, axis=0)
        return tensorflow.reduce_mean(mse * w)
    
    model.compile(loss=custom_loss, optimizer=optimizer)
    # model.compile(loss='mean_squared_error', optimizer=optimizer)

    # Train
    training_history = model.fit(
        data_train_x,
        data_train_y,
        validation_data=(data_val_x, data_val_y),
        batch_size=batch_size,
        epochs=epochs,
        shuffle=True,
        callbacks=callbacks,
        verbose=1,
    )

    # Save model
    model_path = os.path.join(models_dir, f'model_{split_idx:03d}.h5')
    model.save(model_path, save_traces=False, include_optimizer=False)
    print(f"Model saved to {model_path}.")
        
    # Save training loss plot
    fig, ax = pyplot.subplots(1, 1, figsize=(4, 4))
    n_epochs_actual = len(training_history.history['loss'])
    ax.plot(
        numpy.arange(1, n_epochs_actual + 1),
        training_history.history['loss'],
        marker='o',
        label='Training',
    )
    ax.plot(
        numpy.arange(1, n_epochs_actual + 1),
        training_history.history['val_loss'],
        marker='o',
        label='Validation',
    )
    ax.set_yscale('log')
    ax.set_ylim(0.01, 1)
    ax.set_xlabel("Epochs")
    ax.set_ylabel("Loss")
    ax.legend()
    fig.savefig(os.path.join(models_dir, f'model_{split_idx:03d}_training.png'), dpi=200, bbox_inches='tight')
    pyplot.close(fig)

    print(f"Done with model {split_idx + 1}/{len(chr_splits_info)}.")
    print()
        
print("Done.")
# Out:
# Training model 1/10...
# 14,722 samples for training, 1,595 for validation, 1,634 for testing...
# Epoch 1/100
# 116/116 [==============================] - 34s 141ms/step - loss: 0.4252 - val_loss: 0.4356
# Epoch 2/100
# 116/116 [==============================] - 11s 92ms/step - loss: 0.4123 - val_loss: 0.4291
# Epoch 3/100
# 116/116 [==============================] - 11s 92ms/step - loss: 0.4010 - val_loss: 0.4399
# Epoch 4/100
# 116/116 [==============================] - 11s 93ms/step - loss: 0.3655 - val_loss: 0.4645
# Epoch 5/100
# 116/116 [==============================] - 11s 92ms/step - loss: 0.3628 - val_loss: 0.3819
# Epoch 6/100
# 116/116 [==============================] - 11s 95ms/step - loss: 0.3445 - val_loss: 0.3893
# Epoch 7/100
# 116/116 [==============================] - 11s 92ms/step - loss: 0.3426 - val_loss: 0.3756
# Epoch 8/100
# 116/116 [==============================] - 11s 95ms/step - loss: 0.3359 - val_loss: 0.3631
# Epoch 9/100
# 116/116 [==============================] - 11s 93ms/step - loss: 0.3306 - val_loss: 0.3677
# Epoch 10/100
# 116/116 [==============================] - 11s 95ms/step - loss: 0.3291 - val_loss: 0.3680
# Epoch 11/100
# 116/116 [==============================] - 11s 96ms/step - loss: 0
100
# 113/113 [==============================] - 12s 102ms/step - loss: 0.2149 - val_loss: 0.2692
# Epoch 46/100
# 113/113 [==============================] - 11s 101ms/step - loss: 0.2134 - val_loss: 0.2709
# Epoch 47/100
# 113/113 [==============================] - 11s 101ms/step - loss: 0.2118 - val_loss: 0.2703
# Epoch 48/100
# 113/113 [==============================] - 11s 101ms/step - loss: 0.2118 - val_loss: 0.2732
# Epoch 49/100
# 113/113 [==============================] - 12s 102ms/step - loss: 0.2110 - val_loss: 0.2723
# Epoch 50/100
# 113/113 [==============================] - 12s 103ms/step - loss: 0.2093 - val_loss: 0.2753
# Epoch 51/100
# 113/113 [==============================] - 11s 100ms/step - loss: 0.2079 - val_loss: 0.2715
# Epoch 52/100
# 113/113 [==============================] - 12s 102ms/step - loss: 0.2072 - val_loss: 0.2713
# Epoch 53/100
# 113/113 [==============================] - 11s 101ms/step - loss: 0.2058 - val_loss: 0.2734
# Epoch 54/100
# 113/113 [==============================] - 12s 102ms/step - loss: 0.2061 - val_loss: 0.2721
# Epoch 55/100
# 113/113 [==============================] - 12s 102ms/step - loss: 0.2053 - val_loss: 0.2719
# Model saved to models_rnn_attn\model_003.h5.
# Done with model 4/10.
#
# Training model 5/10...
# 13,945 samples for training, 2,007 for validation, 1,999 for testing...
# Epoch 1/100
# 109/109 [==============================] - 34s 161ms/step - loss: 0.4286 - val_loss: 0.4275
# Epoch 2/100
# 109/109 [==============================] - 11s 102ms/step - loss: 0.4145 - val_loss: 0.4174
# Epoch 3/100
# 109/109 [==============================] - 11s 103ms/step - loss: 0.4034 - val_loss: 0.3987
# Epoch 4/100
# 109/109 [==============================] - 11s 101ms/step - loss: 0.3667 - val_loss: 0.3637
# Epoch 5/100
# 109/109 [==============================] - 11s 102ms/step - loss: 0.3470 - val_loss: 0.3476
# Epoch 6/100
# 109/109 [==============================] - 11s 104ms/step - loss: 0.3358 - val_loss: 0.3395
# Epoch 7/100
# 109/109 [==============================] - 11s 103ms/step - loss: 0.3309 - val_loss: 0.3399
# Epoch 8/100
# 109/109 [==============================] - 11s 103ms/step - loss: 0.3247 - val_loss: 0.3370
# Epoch 9/100
# 109/109 [==============================] - 11s 102ms/step - loss: 0.3155 - val_loss: 0.3304
# Epoch 10/100
# 109/109 [==============================] - 11s 102ms/step - loss: 0.3128 - val_loss: 0.3321
# Epoch 11/100
# 109/109 [==============================] - 11s 103ms/step - loss: 0.3068 - val_loss: 0.3237
# Epoch 12/100
# 109/109 [==============================] - 11s 102ms/step - loss: 0.2985 - val_loss: 0.3175
# Epoch 13/100
# 109/109 [==============================] - 11s 103ms/step - loss: 0.2907 - val_loss: 0.3105
# Epoch 14/100
# 109/109 [==============================] - 11s 102ms/step - loss: 0.2863 - val_loss: 0.2986
# Epoch 15/100
# 109/109 [==============================] - 11s 102ms/step - loss: 0.2777 - val_loss: 0.2907
# Epoch 16/100
# 109/109 [==============================] - 11s 102ms/step - loss: 0.2683 - val_loss: 0.2886
# Epoch 17/100
# 109/109 [==============================] - 11s 101ms/step - loss: 0.2634 - val_loss: 0.2844
# Epoch 18/100
# 109/109 [==============================] - 11s 102ms/step - loss: 0.2578 - val_loss: 0.2857
# Epoch 19/100
# 109/109 [==============================] - 12s 106ms/step - loss: 0.2580 - val_loss: 0.2841
# Epoch 20/100
# 109/109 [==============================] - 11s 102ms/step - loss: 0.2507 - val_loss: 0.2810
# Epoch 21/100
# 109/109 [==============================] - 11s 102ms/step - loss: 0.2501 - val_loss: 0.2803
# Epoch 22/100
# 109/109 [==============================] - 11s 101ms/step - loss: 0.2459 - val_loss: 0.2790
# Epoch 23/100
# 109/109 [==============================] - 11s 102ms/step - loss: 0.2438 - val_loss: 0.2824
# Epoch 24/100
# 109/109 [==============================] - 11s 103ms/step - loss: 0.2406 - val_loss: 0.2791
# Epoch 25/100
# 109/109 [==============================] - 11s 103ms/step - loss: 0.2373 - val_loss: 0.2755
# Epoch 26/100
# 109/109 [==============================] - 11s 103ms/step - loss: 0.2345 - val_loss: 0.2768
# Epoch 27/100
# 109/109 [==============================] - 11s 102ms/step - loss: 0.2319 - val_loss: 0.2784
# Epoch 28/100
# 109/109 [==============================] - 11s 103ms/step - loss: 0.2305 - val_loss: 0.2751
# Epoch 29/100
# 109/109 [==============================] - 11s 101ms/step - loss: 0.2297 - val_loss: 0.2769
# Epoch 30/100
# 109/109 [==============================] - 11s 103ms/step - loss: 0.2262 - val_loss: 0.2758
# Epoch 31/100
# 109/109 [==============================] - 11s 102ms/step - loss: 0.2248 - val_loss: 0.2721
# Epoch 32/100
# 109/109 [==============================] - 11s 102ms/step - loss: 0.2236 - val_loss: 0.2749
# Epoch 33/100
# 109/109 [==============================] - 11s 101ms/step - loss: 0.2237 - val_loss: 0.2745
# Epoch 34/100
# 109/109 [==============================] - 11s 102ms/step - loss: 0.2205 - val_loss: 0.2719
# Epoch 35/100
# 109/109 [==============================] - 11s 102ms/step - loss: 0.2192 - val_loss: 0.2744
# Epoch 36/100
# 109/109 [==============================] - 11s 102ms/step - loss: 0.2177 - val_loss: 0.2773
# Epoch 37/100
# 109/109 [==============================] - 11s 102ms/step - loss: 0.2159 - val_loss: 0.2773
# Epoch 38/100
# 109/109 [==============================] - 11s 102ms/step - loss: 0.2163 - val_loss: 0.2732
# Epoch 39/100
# 109/109 [==============================] - 11s 101ms/step - loss: 0.2149 - val_loss: 0.2748
# Epoch 40/100
# 109/109 [==============================] - 11s 103ms/step - loss: 0.
100
# 113/113 [==============================] - 12s 102ms/step - loss: 0.2179 - val_loss: 0.2668
# Epoch 39/100
# 113/113 [==============================] - 11s 101ms/step - loss: 0.2174 - val_loss: 0.2655
# Epoch 40/100
# 113/113 [==============================] - 12s 104ms/step - loss: 0.2164 - val_loss: 0.2682
# Epoch 41/100
# 113/113 [==============================] - 12s 103ms/step - loss: 0.2141 - val_loss: 0.2650
# Epoch 42/100
# 113/113 [==============================] - 11s 101ms/step - loss: 0.2133 - val_loss: 0.2659
# Epoch 43/100
# 113/113 [==============================] - 11s 101ms/step - loss: 0.2128 - val_loss: 0.2646
# Model saved to models_rnn_attn\model_005.h5.
# Done with model 6/10.
#
# Training model 7/10...
# 14,412 samples for training, 2,020 for validation, 1,519 for testing...
# Epoch 1/100
# 113/113 [==============================] - 33s 152ms/step - loss: 0.4283 - val_loss: 0.4419
# Epoch 2/100
# 113/113 [==============================] - 11s 102ms/step - loss: 0.4178 - val_loss: 0.4307
# Epoch 3/100
# 113/113 [==============================] - 12s 103ms/step - loss: 0.4071 - val_loss: 0.4115
# Epoch 4/100
# 113/113 [==============================] - 12s 103ms/step - loss: 0.3707 - val_loss: 0.3647
# Epoch 5/100
# 113/113 [==============================] - 11s 101ms/step - loss: 0.3514 - val_loss: 0.3652
# Epoch 6/100
# 113/113 [==============================] - 12s 103ms/step - loss: 0.3419 - val_loss: 0.3507
# Epoch 7/100
# 113/113 [==============================] - 12s 103ms/step - loss: 0.3349 - val_loss: 0.3541
# Epoch 8/100
# 113/113 [==============================] - 12s 103ms/step - loss: 0.3326 - val_loss: 0.3424
# Epoch 9/100
# 113/113 [==============================] - 12s 102ms/step - loss: 0.3261 - val_loss: 0.3357
# Epoch 10/100
# 113/113 [==============================] - 12s 104ms/step - loss: 0.3199 - val_loss: 0.3306
# Epoch 11/100
# 113/113 [==============================] - 12s 103ms/step - loss: 0.3170 - val_loss: 0.3281
# Epoch 12/100
# 113/113 [==============================] - 12s 103ms/step - loss: 0.3132 - val_loss: 0.3305
# Epoch 13/100
# 113/113 [==============================] - 11s 102ms/step - loss: 0.3079 - val_loss: 0.3288
# Epoch 14/100
# 113/113 [==============================] - 12s 104ms/step - loss: 0.3033 - val_loss: 0.3241
# Epoch 15/100
# 113/113 [==============================] - 12s 104ms/step - loss: 0.2992 - val_loss: 0.3231
# Epoch 16/100
# 113/113 [==============================] - 12s 103ms/step - loss: 0.2977 - val_loss: 0.3227
# Epoch 17/100
# 113/113 [==============================] - 12s 104ms/step - loss: 0.2938 - val_loss: 0.3207
# Epoch 18/100
# 113/113 [==============================] - 12s 102ms/step - loss: 0.2883 - val_loss: 0.3110
# Epoch 19/100
# 113/113 [==============================] - 12s 103ms/step - loss: 0.2857 - val_loss: 0.3136
# Epoch 20/100
# 113/113 [==============================] - 12s 102ms/step - loss: 0.2829 - val_loss: 0.3131
# Epoch 21/100
# 113/113 [==============================] - 12s 104ms/step - loss: 0.2790 - val_loss: 0.3100
# Epoch 22/100
# 113/113 [==============================] - 12s 104ms/step - loss: 0.2764 - val_loss: 0.3089
# Epoch 23/100
# 113/113 [==============================] - 12s 103ms/step - loss: 0.2741 - val_loss: 0.3058
# Epoch 24/100
# 113/113 [==============================] - 12s 103ms/step - loss: 0.2727 - val_loss: 0.3040
# Epoch 25/100
# 113/113 [==============================] - 12s 103ms/step - loss: 0.2677 - val_loss: 0.3040
# Epoch 26/100
# 113/113 [==============================] - 12s 103ms/step - loss: 0.2658 - val_loss: 0.3052
# Epoch 27/100
# 113/113 [==============================] - 12s 103ms/step - loss: 0.2643 - val_loss: 0.3017
# Epoch 28/100
# 113/113 [==============================] - 12s 103ms/step - loss: 0.2625 - val_loss: 0.3024
# Epoch 29/100
# 113/113 [==============================] - 12s 103ms/step - loss: 0.2595 - val_loss: 0.3034
# Epoch 30/100
# 113/113 [==============================] - 12s 102ms/step - loss: 0.2576 - val_loss: 0.3030
# Epoch 31/100
# 113/113 [==============================] - 11s 101ms/step - loss: 0.2563 - val_loss: 0.3040
# Epoch 32/100
# 113/113 [==============================] - 12s 103ms/step - loss: 0.2543 - val_loss: 0.3016
# Epoch 33/100
# 113/113 [==============================] - 12s 103ms/step - loss: 0.2511 - val_loss: 0.3092
# Epoch 34/100
# 113/113 [==============================] - 11s 101ms/step - loss: 0.2510 - val_loss: 0.3013
# Epoch 35/100
# 113/113 [==============================] - 12s 103ms/step - loss: 0.2474 - val_loss: 0.2993
# Epoch 36/100
# 113/113 [==============================] - 12s 103ms/step - loss: 0.2453 - val_loss: 0.2982
# Epoch 37/100
# 113/113 [==============================] - 12s 104ms/step - loss: 0.2419 - val_loss: 0.3023
# Epoch 38/100
# 113/113 [==============================] - 12s 102ms/step - loss: 0.2411 - val_loss: 0.2996
# Epoch 39/100
# 113/113 [==============================] - 12s 102ms/step - loss: 0.2397 - val_loss: 0.2984
# Epoch 40/100
# 113/113 [==============================] - 12s 102ms/step - loss: 0.2375 - val_loss: 0.2950
# Epoch 41/100
# 113/113 [==============================] - 12s 103ms/step - loss: 0.
100
# 112/112 [==============================] - 12s 104ms/step - loss: 0.2118 - val_loss: 0.2644
# Epoch 51/100
# 112/112 [==============================] - 12s 103ms/step - loss: 0.2117 - val_loss: 0.2621
# Epoch 52/100
# 112/112 [==============================] - 12s 108ms/step - loss: 0.2102 - val_loss: 0.2620
# Epoch 53/100
# 112/112 [==============================] - 12s 105ms/step - loss: 0.2077 - val_loss: 0.2654
# Epoch 54/100
# 112/112 [==============================] - 12s 105ms/step - loss: 0.2089 - val_loss: 0.2648
# Epoch 55/100
# 112/112 [==============================] - 12s 104ms/step - loss: 0.2063 - val_loss: 0.2625
# Epoch 56/100
# 112/112 [==============================] - 12s 103ms/step - loss: 0.2077 - val_loss: 0.2618
# Model saved to models_rnn_attn\model_009.h5.
# Done with model 10/10.
#
# Done.

# %% [markdown]
# # Make average model

# %%
# Input
model_input = layers.Input(shape=(None, 4))
model_list = []
model_outputs = []

# Load models
for split_idx, chr_split_info in enumerate(chr_splits_info):
    model_path = os.path.join(models_dir, f'model_{split_idx:03d}.h5')
    
    model = rnn_attn.load_model(model_path)
    model_list.append(model)
    
    model_output = model(model_input)
    model_outputs.append(model_output)
    
# Model output: average of bs model outputs
model_bs_output = layers.Average()(model_outputs)

# Define bootstrapped model
model_bs = models.Model(
    model_input,
    model_bs_output,
)
model_bs.save(os.path.join(models_dir, f'model_avg.h5'), save_traces=False, include_optimizer=False)
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# c:\Users\casti\miniconda3\lib\site-packages\keras\engine\functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)

# %% [markdown]
# # Evaluate models
#
# To get precise performance metrics, evaluation is run on a held-out test dataset which is different for each of the 10 models. These are reported in Figure 5.

# %%
# Load models
model_list = []
for split_idx, chr_split_info in enumerate(chr_splits_info):
    model_path = os.path.join(models_dir, f'model_{split_idx:03d}.h5')
    
    model = rnn_attn.load_model(model_path)
    model_list.append(model)
    
model_list
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# [<keras.engine.functional.Functional at 0x14c9076e580>,
#  <keras.engine.functional.Functional at 0x14c9098d850>,
#  <keras.engine.functional.Functional at 0x14e8e492e20>,
#  <keras.engine.functional.Functional at 0x14e8870b340>,
#  <keras.engine.functional.Functional at 0x14ec4c09ac0>,
#  <keras.engine.functional.Functional at 0x14f150b3220>,
#  <keras.engine.functional.Functional at 0x14e86e55ee0>,
#  <keras.engine.functional.Functional at 0x14ec4bf3190>,
#  <keras.engine.functional.Functional at 0x14e7f5c8bb0>,
#  <keras.engine.functional.Functional at 0x14ee0878d90>]

# %%
# Add predictions to data
# For each model, predict only on its test set given by its chromosomal split
# Compute performance metrics too

r2_list = []

for split_idx, chr_split_info in enumerate(chr_splits_info):
    print(f"Evaluating model trained on data split {split_idx}...")

    # Select data from test chromosomes
    test_chrs = chr_split_info['test']
    data_test = data[data['chr'].isin(test_chrs)]

    data_test_x = seq_utils.one_hot_encode(data_test['insert_seq'], padding='left', mask_val=-1)
    data_test_y = data_test[res_log2_mrl_cols + res_delta_log2_x_cols].values

    # Load model and generate prediction
    model = model_list[split_idx]
    data_test_y_pred = model.predict(data_test_x)
    
    # Add to dataframe
    for output_idx, output_name in enumerate(log2_mrl_cols + delta_log2_x_cols):
        data.loc[data_test.index, 'pred_rnn_test_' + output_name] = data_test_y_pred[:, output_idx]

    # Calculate r^2 on each output
    r2_outputs_list = []
    for output_idx, output_label in enumerate(res_log2_mrl_cols + res_delta_log2_x_cols):
        # Calculate overall R^2
        lrres = scipy.stats.linregress(
            data_test_y[:, output_idx],
            data_test_y_pred[:, output_idx],
        )
        r2_outputs_list.append(lrres.rvalue**2)
    r2_list.append(r2_outputs_list)

r2_test_df = pandas.DataFrame(r2_list, columns=res_log2_mrl_cols + res_delta_log2_x_cols)
r2_test_df
# Out:
# Evaluating model trained on data split 0...
# C:\Users\casti\AppData\Local\Temp\ipykernel_35648\262040866.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.loc[data_test.index, 'pred_rnn_test_' + output_name] = data_test_y_pred[:, output_idx]
# C:\Users\casti\AppData\Local\Temp\ipykernel_35648\262040866.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.loc[data_test.index, 'pred_rnn_test_' + output_name] = data_test_y_pred[:, output_idx]
# C:\Users\casti\AppData\Local\Temp\ipykernel_35648\262040866.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.loc[data_test.index, 'pred_rnn_test_' + output_name] = data_test_y_pred[:, output_idx]
# C:\Users\casti\AppData\Local\Temp\ipykernel_35648\262040866.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.loc[data_test.index, 'pred_rnn_test_' + output_name] = data_test_y_pred[:, output_idx]
# C:\Users\casti\AppData\Local\Temp\ipykernel_35648\262040866.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.loc[data_test.index, 'pred_rnn_test_' + output_name] = data_test_y_pred[:, output_idx]
# C:\Users\casti\AppData\Local\Temp\ipykernel_35648\262040866.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.loc[data_test.index, 'pred_rnn_test_' + output_name] = data_test_y_pred[:, output_idx]
# C:\Users\casti\AppData\Local\Temp\ipykernel_35648\262040866.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.loc[data_test.index, 'pred_rnn_test_' + output_name] = data_test_y_pred[:, output_idx]
# C:\Users\casti\AppData\Local\Temp\ipykernel_35648\262040866.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.loc[data_test.index, 'pred_rnn_test_' + output_name] = data_test_y_pred[:, output_idx]
# Evaluating model trained on data split 1...
# Evaluating model trained on data split 2...
# Evaluating model trained on data split 3...
# Evaluating model trained on data split 4...
# Evaluating model trained on data split 5...
# Evaluating model trained on data split 6...
# Evaluating model trained on data split 7...
# Evaluating model trained on data split 8...
# Evaluating model trained on data split 9...
#    res_log2_MRL_2hpf  res_log2_MRL_4hpf  res_log2_MRL_6hpf  \
# 0           0.535130           0.471615           0.445447
# 1           0.508299           0.418119           0.437297
# 2           0.530117           0.492690           0.469777
# 3           0.434385           0.374020           0.376056
# 4           0.517246           0.438543           0.430223
# 5           0.488769           0.405901           0.389848
# 6           0.475108           0.410823           0.366221
# 7           0.471604           0.411130           0.424354
# 8           0.476026           0.396516           0.401772
# 9           0.481891           0.413383           0.377195
#
#    res_log2_MRL_10hpf  res_Δlog2_X_2hpf  res_Δlog2_X_4hpf  res_Δlog2_X_6hpf  \
# 0            0.543914          0.412684          0.431829          0.387097
# 1            0.519000          0.409233          0.341525          0.295686
# 2            0.555339          0.434125          0.359012          0.320336
# 3            0.498749          0.360524          0.321817          0.336675
# 4            0.545501          0.390410          0.385171          0.331457
# 5            0.481572          0.389619          0.368814          0.365403
# 6            0.434996          0.343019          0.373553          0.266022
# 7            0.499294          0.370125          0.356212          0.312327
# 8            0.471557          0.394523          0.413383          0.340810
# 9            0.479734          0.316110          0.353393          0.327845
#
#    res_Δlog2_X_10hpf
# 0           0.388377
# 1           0.407162
# 2           0.398302
# 3           0.356195
# 4           0.375178
# 5           0.354029
# 6           0.300598
# 7           0.336838
# 8           0.342024
# 9           0.296943

# %%
# Save performance metrics
r2_test_df.to_csv('performance_rnn_test_r2.csv')
r2_test_df
# Out:
#    res_log2_MRL_2hpf  res_log2_MRL_4hpf  res_log2_MRL_6hpf  \
# 0           0.535130           0.471615           0.445447
# 1           0.508299           0.418119           0.437297
# 2           0.530117           0.492690           0.469777
# 3           0.434385           0.374020           0.376056
# 4           0.517246           0.438543           0.430223
# 5           0.488769           0.405901           0.389848
# 6           0.475108           0.410823           0.366221
# 7           0.471604           0.411130           0.424354
# 8           0.476026           0.396516           0.401772
# 9           0.481891           0.413383           0.377195
#
#    res_log2_MRL_10hpf  res_Δlog2_X_2hpf  res_Δlog2_X_4hpf  res_Δlog2_X_6hpf  \
# 0            0.543914          0.412684          0.431829          0.387097
# 1            0.519000          0.409233          0.341525          0.295686
# 2            0.555339          0.434125          0.359012          0.320336
# 3            0.498749          0.360524          0.321817          0.336675
# 4            0.545501          0.390410          0.385171          0.331457
# 5            0.481572          0.389619          0.368814          0.365403
# 6            0.434996          0.343019          0.373553          0.266022
# 7            0.499294          0.370125          0.356212          0.312327
# 8            0.471557          0.394523          0.413383          0.340810
# 9            0.479734          0.316110          0.353393          0.327845
#
#    res_Δlog2_X_10hpf
# 0           0.388377
# 1           0.407162
# 2           0.398302
# 3           0.356195
# 4           0.375178
# 5           0.354029
# 6           0.300598
# 7           0.336838
# 8           0.342024
# 9           0.296943

# %%
residual_axis_limits = [
    (-3.5, 3), # log2_MRL
    (-4, 4), # Δlog2_MRL
    (-3, 3), # Δlog2_X
    (-4, 4), # log2_X
]

# %%
# Plot performance per ensemble member
for split_idx, chr_split_info in enumerate(chr_splits_info):
    print(f"Evaluating model trained on data split {split_idx}...")

    # Select data from test chromosomes
    test_chrs = chr_split_info['test']
    data_test = data[data['chr'].isin(test_chrs)]
    
    # Plot
    fig = custom_plots.plot_pred_vs_obs(
        data_test,
        obs_col_prefix='res',
        pred_col_prefix='pred_rnn_test',
        axis_limits=residual_axis_limits,
    )

    fig.savefig(os.path.join(models_dir, f'model_{split_idx:03d}_performance.png'), dpi=200, bbox_inches='tight')
    fig.savefig(os.path.join(models_dir, f'model_{split_idx:03d}_performance.svg'), dpi=200, bbox_inches='tight')
    pyplot.close(fig)
# Out:
# Evaluating model trained on data split 0...
# Evaluating model trained on data split 1...
# Evaluating model trained on data split 2...
# Evaluating model trained on data split 3...
# Evaluating model trained on data split 4...
# Evaluating model trained on data split 5...
# Evaluating model trained on data split 6...
# Evaluating model trained on data split 7...
# Evaluating model trained on data split 8...
# Evaluating model trained on data split 9...

# %%
# Combined performance of all models in their test sets
fig = custom_plots.plot_pred_vs_obs(
        data,
        obs_col_prefix='res',
        pred_col_prefix='pred_rnn_test',
        axis_limits=residual_axis_limits,
)

fig.savefig(os.path.join(models_dir, f'model_all_test_performance.png'), dpi=200, bbox_inches='tight')
fig.savefig(os.path.join(models_dir, f'model_all_test_performance.svg'), dpi=200, bbox_inches='tight')

# %%
# Save RNN predictions on the test set
data_pred_rnn_test = data[['pred_rnn_test_' + c for c in log2_mrl_cols + delta_log2_x_cols]]
data_pred_rnn_test.to_csv('Zb_5UTR_MPRA_rnn_test_predictions.tsv.gz', sep='\t', compression='gzip')
data_pred_rnn_test
# Out:
#                                                     pred_rnn_test_log2_MRL_2hpf  \
# ENSDARG00000000001_ENSDART00000000004_19058_slc
# ENSDARG00000056892_ENSDART00000148517_5556_mpp6...                    0.198111
#
#                                                     pred_rnn_test_Δlog2_X_10hpf
# ENSDARG00000000001_ENSDART00000000004_19058_slc...                    -0.185110
# ENSDARG00000000018_ENSDART00000181044_14421_nrf...                     0.013057
# ENSDARG00000000019_ENSDART00000124452_14118_ube...                     0.016827
# ENSDARG00000000068_ENSDART00000000069_2438_slc9...                     0.430732
# ENSDARG00000000069_ENSDART00000000070_12170_dap...                    -0.148420
# ...                                                                         ...
# ENSDARG00000060397_ENSDART00000085051_231_hhip_...                    -0.339029
# ENSDARG00000098284_ENSDART00000170620_10459_ctx...                    -0.203468
# ENSDARG00000103318_ENSDART00000161570_7325_mrpl...                    -0.174170
# ENSDARG00000036698_ENSDART00000053300_7697_znf8...                    -0.368123
# ENSDARG00000056892_ENSDART00000148517_5556_mpp6...                     0.338540
#
# [17951 rows x 8 columns]

# %% [markdown]
# # Generate model ensemble predictions
#
# Here we generate predictions for all sequences using the average of the individual model outputs.

# %%
# Add ensemble predictions
data_x = seq_utils.one_hot_encode(data['insert_seq'], padding='left', mask_val=-1)

model_preds = []
for model_idx, model in enumerate(model_list):
    data_y_pred = model.predict(data_x)
    model_preds.append(data_y_pred)

# Average predictions
data_y_pred = numpy.mean(model_preds, axis=0)

# Add to dataframe
for output_idx, output_name in enumerate(log2_mrl_cols + delta_log2_x_cols):
    data['pred_rnn_ens_' + output_name] = data_y_pred[:, output_idx]
# Out:
# C:\Users\casti\AppData\Local\Temp\ipykernel_35648\1421581488.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['pred_rnn_ens_' + output_name] = data_y_pred[:, output_idx]
# C:\Users\casti\AppData\Local\Temp\ipykernel_35648\1421581488.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['pred_rnn_ens_' + output_name] = data_y_pred[:, output_idx]
# C:\Users\casti\AppData\Local\Temp\ipykernel_35648\1421581488.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['pred_rnn_ens_' + output_name] = data_y_pred[:, output_idx]
# C:\Users\casti\AppData\Local\Temp\ipykernel_35648\1421581488.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['pred_rnn_ens_' + output_name] = data_y_pred[:, output_idx]
# C:\Users\casti\AppData\Local\Temp\ipykernel_35648\1421581488.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['pred_rnn_ens_' + output_name] = data_y_pred[:, output_idx]
# C:\Users\casti\AppData\Local\Temp\ipykernel_35648\1421581488.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['pred_rnn_ens_' + output_name] = data_y_pred[:, output_idx]
# C:\Users\casti\AppData\Local\Temp\ipykernel_35648\1421581488.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['pred_rnn_ens_' + output_name] = data_y_pred[:, output_idx]
# C:\Users\casti\AppData\Local\Temp\ipykernel_35648\1421581488.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['pred_rnn_ens_' + output_name] = data_y_pred[:, output_idx]

# %%
# Plot ensemble model performance
fig = custom_plots.plot_pred_vs_obs(
        data,
        obs_col_prefix='res',
        pred_col_prefix='pred_rnn_ens',
        axis_limits=residual_axis_limits,
)

fig.savefig(f'model_rnn_ensemble_performance.png', dpi=200, bbox_inches='tight')
fig.savefig(f'model_rnn_ensemble_performance.svg', dpi=200, bbox_inches='tight')

# %%
# Save spreadsheet with predictions
data_pred_rnn_ens = data[['pred_rnn_ens_' + c for c in log2_mrl_cols + delta_log2_x_cols]]
data_pred_rnn_ens.to_csv('Zb_5UTR_MPRA_rnn_ensemble_predictions.tsv.gz', sep='\t', compression='gzip')
